# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path2csv = './csv/'#'/Users/klara/Downloads/'
path2plots = './plots/convergence/'

# %% [markdown]
# # preparation of data

# %%
def csv_to_df(path2csv):
    dff_all_from_csv = []
    print(path2csv)
    
    for root, dirs, files in os.walk(path2csv):
        print(root, files)
        for file in files:
            if not file.endswith('.csv'):
                continue
            df = pd.read_csv(os.path.join(root, file), skiprows=range(0,6))
            df.set_index(['[run number]', '[step]'], inplace=True)
            dff_all_from_csv.append(df)
    return dff_all_from_csv

# %%
dff_all_from_csv = csv_to_df(path2csv)
# Out:
# ./csv/
# ./csv/ ['Language Change_converge_stop experiment8-reward-alpha-table.csv', 'Language Change_converge_stop experiment1-individual-perc-table.csv', 'Language Change_converge_stop experiment3-threshold-perc-table.csv', 'Language Change_converge_stop experiment2-threshold-perc-thres-table.csv', 'Language Change_converge_stop experiment4-reward-perc-table.csv', 'Language Change_converge_stop experiment6-threshold-sink-state-table.csv', 'Language Change_converge_stop experiment5-threshold-thres-table.csv', 'Language Change_converge_stop experiment7-reward-logistic-table.csv']

# %%
dff_all_from_csv[0]
# Out:
#                      logistic?  alpha update-algorithm  num-nodes  \
# [run number] [step]
# 6            0            True   0.00           reward        100
# 7            0            True   0.00           reward        100
# 6            1            True   0.00           reward        100
# 7            1            True   0.00           reward        100
#              2            True   0.00           reward        100
# ...                        ...    ...              ...        ...
# 543          977          True   0.05           reward        100
#              978          True   0.05           reward        100
#              979          True   0.05           reward        100
#              980          True   0.05           reward        100
#              981          True   0.05           reward        100
#
#                      percent-grammar-1  sink-state-1?  threshold-val  \
# [run number] [step]
# 6            0                      60           True            0.3
# 7            0                      60           True            0.3
# 6            1                      60           True            0.3
# 7            1                      60           True            0.3
#              2                      60           True            0.3
# ...                                ...            ...            ...
# 543          977                    60           True            0.3
#              978                    60           True            0.3
#              979                    60           True            0.3
#              980                    60           True            0.3
#              981                    60           True            0.3
#
#                      final-grammar1-distribution
# [run number] [step]
# 6            0                          0.600000
# 7            0                          0.600000
# 6            1                          0.600147
# 7            1                          0.600074
#              2                          0.599624
# ...                                          ...
# 543          977                        0.989519
#              978                        0.989631
#              979                        0.989742
#              980                        0.989851
#              981                        0.989959
#
# [2454790 rows x 8 columns]

# %% [markdown]
# # display results wrt. # steps until convergence

# %%
def plot_run_length(df):
    # determine type of grammar spread
    infection_type = df['update-algorithm'].iloc[0]

    # set parameters tested in experiment
    if infection_type == 'individual' or infection_type == 'threshold':
        params = ['threshold-val', 'percent-grammar-1']
    else:
        params = ['alpha', 'logistic?']

    # display results of experiment for each parameter
    for p in params:
        vals, counts = np.unique(df[p], return_counts=True)
        if len(vals) == 1:
            # if only one value for parameter, no need to plot
            continue

        # check whether effect of tested parameter is statistical relevant to # steps until convergence
        temp_df = df.reset_index(inplace=False).groupby([p, "[run number]"]).max()["[step]"]
        # df stores distribution of # steps until convergence for each parameter value across multiple runs
        exp_result_distr_for_param = temp_df.reset_index(inplace=False).groupby(p).agg({'[step]': ['mean', 'min', 'max', 'std']})
        display(exp_result_distr_for_param)
        plt.plot(exp_result_distr_for_param.index.values, exp_result_distr_for_param['[step]']['mean'], label="mean")
        plt.plot(exp_result_distr_for_param.index.values, exp_result_distr_for_param['[step]']['mean'] + exp_result_distr_for_param['[step]']['std'], label="std", c="r")
        plt.plot(exp_result_distr_for_param.index.values, exp_result_distr_for_param['[step]']['mean'] - exp_result_distr_for_param['[step]']['std'], c="r")
        plt.plot(exp_result_distr_for_param.index.values, exp_result_distr_for_param['[step]']['max'] , c="g", linestyle="--", label="max")
        plt.xlabel(p)
        plt.legend()
        plt.title(infection_type + ': # steps until convergence for different values of ' + p)
        plt.savefig(path2plots + infection_type + '_steps_until_convergence_' + p + '.png', bbox_inches='tight')
        plt.show()

        # display std for different values of p
        plt.figure()
        plt.plot(exp_result_distr_for_param.index.values, exp_result_distr_for_param['[step]']['std'], label="std")
        plt.title(infection_type + ': std of # steps until convergence for different values of ' + p)
        plt.xlabel(p)
        plt.ylabel('std')
        plt.savefig(path2plots + infection_type + '_std_steps_until_convergence_' + p + '.png', bbox_inches='tight')
        plt.show()
        # TODO: docu is wrong, bc std for p=0.9 threshold too high (-> sink-state not wokring for individual)

for experiment_df in dff_all_from_csv:
    # check whether combinatorial experiment worked
    print("new experiment")
    plot_run_length(experiment_df)
# Out:
# new experiment
#          [step]
#            mean  min    max          std
# alpha
# 0.000  19494.80  619  20000  2847.929610
# 0.005  12999.12  474  20000  9167.339045
# 0.010   7363.10  398  20000  9227.462333
# 0.015   4001.68  381  20000  7573.234700
# 0.020   2561.74  370  20000  5817.159889
# 0.025    798.36  352  20000  2772.624519
# 0.030    389.02  353    907    77.907714
# 0.035    367.90  344    483    19.315057
# 0.040    379.40  345   1189   117.421098
# 0.045    361.96  335    619    38.176796
# 0.050    367.72  340    981    89.177429
# new experiment
#                   [step]
#                     mean min  max        std
# percent-grammar-1
# 10                 26.36   0  183  42.060093
# 20                 57.56   4  200  59.364718
# 30                 55.30   6  200  46.307865
# 40                 73.32   5  200  62.633511
# 50                 70.02   8  200  52.324923
# 60                 66.08   8  200  55.936859
# 70                 46.34   2  200  39.487849
# 80                 56.14   2  200  54.591623
# 90                 28.60   0  200  44.025503
# new experiment
#                    [step]
#                      mean  min  max        std
# percent-grammar-1
# 10                 200.00  200  200   0.000000
# 20                 196.06    3  200  27.860007
# 30                 140.78    2  200  91.379069
# 40                  61.44    1  200  91.631284
# 50                  25.48    1  200  65.103133
# 60                   5.34    1  200  28.096488
# 70                   0.98    0    2   0.377424
# 80                   0.70    0    1   0.462910
# 90                   0.36    0    1   0.484873
# new experiment
#                    [step]
#                      mean min  max        std
# threshold-val
# 0.1              3.014815   0  200  17.080167
# 0.2             30.840741   0  200  70.681971
# 0.3             70.481481   0  200  94.832927
# 0.4            107.140741   0  200  99.456266
# 0.5            111.525926   0  200  99.101752
# 0.6            171.159259   0  200  70.321412
# 0.7            178.540741   0  200  61.977063
# 0.8            187.151852   0  200  48.764390
# 0.9            191.111111   0  200  41.292621
#                        [step]
#                          mean min  max        std
# percent-grammar-1
# 10                 178.148148   2  200  61.921886
# 20                 160.548148   1  200  79.051037
# 30                 150.229630   1  200  85.941230
# 40                 137.614815   1  200  92.207942
# 50                 124.288889   1  200  96.584718
# 60                  98.429630   0  200  99.522917
# 70                  90.262963   0  200  99.074159
# 80                  75.966667   0  200  96.826306
# 90                  35.477778   0  200  76.075910
# new experiment
# new experiment
# new experiment
#                [step]
#                  mean  min  max        std
# threshold-val
# 0.1              1.14    0    2   0.404566
# 0.2              1.34    1    3   0.519419
# 0.3              9.24    0  200  39.337140
# 0.4             76.90    0  200  97.352767
# 0.5             65.02    1  200  93.536742
# 0.6            200.00  200  200   0.000000
# 0.7            200.00  200  200   0.000000
# 0.8            200.00  200  200   0.000000
# 0.9            200.00  200  200   0.000000
# new experiment
#            [step]
#              mean  min    max          std
# logistic?
# False      353.24  335    391     7.596012
# True       800.78  349  20000  2761.222715
